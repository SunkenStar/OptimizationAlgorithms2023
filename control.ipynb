# %%
import control as ct
import matplotlib.pyplot as plt
import numpy as np

# %%
s = ct.tf([1, 0], [1])

# %%
K_amp = 0.05

# %%
G_valve = 3.06*10**-3/(s**2/600**2+2*0.5*s/600+1)

# %%
G_motor = 1.25*10**6/(s**2/388**2+2*0.94*s/388+1)

# %%
K_gear = 3

# %%
K_sensor = 0.175

# %%
G = K_amp * G_valve * G_motor * K_gear * K_sensor
G
# Out:
# TransferFunction(array([1.26680473e+18]), array([2.32800000e+05, 3.09493632e+08, 2.20742822e+11, 8.21608934e+13,
#        1.26167916e+16]))

# %%
ct.bode(G, omega = np.logspace(start = 0, stop = 4, num = 200), dB=True, deg=True)
plt.show()
ct.margin(G)
# Out:
# (0.023347926780977846,
#  -128.3276109320512,
#  515.2366143869341,
#  1535.2462985398608)

# %%
Gc_amp = 1/s

# %%
G_hat1 = Gc_amp * G
G_hat1
# Out:
# TransferFunction(array([1.26680473e+18]), array([2.32800000e+05, 3.09493632e+08, 2.20742822e+11, 8.21608934e+13,
#        1.26167916e+16, 0.00000000e+00]))

# %%
ct.bode(G_hat1, omega = np.logspace(start = 0, stop = 4, num = 200), dB=True, deg=True)
plt.show()
ct.margin(G_hat1)
# Out:
# (3.0504142086066155, 53.95384088559814, 247.16832478958648, 96.98527580242953)

# %%
a=2.205
b=0.006
T1=0.878
T2=1.450
Gc2=(a*T1*s+1)/(T1*s+1) * (b*T2*s+1)/(T2*s+1)

# %%
G_hat2 = Gc2 * G
ct.bode(G_hat2, omega = np.logspace(start = 0, stop = 4, num = 200), dB=True, deg=True)
plt.show()
ct.margin(G_hat2)
# Out:
# (1.5014376681583823, 45.554861608055006, 473.5762845930015, 319.56797700140953)

# %%
G_hat2
# Out:
# TransferFunction(array([2.13369352e+16, 2.46354248e+18, 1.26680473e+18]), array([2.96377680e+05, 3.94558301e+08, 2.81748421e+11, 1.05113232e+14,
#        1.62539286e+16, 2.94540516e+16, 1.26167916e+16]))
